# %% [markdown]
# <a href="https://colab.research.google.com/github/khushi1315/Machine-Learning_Practice/blob/main/Polynomial_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Polynomial Regression

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
df=pd.read_csv('Position_Salaries.csv')
x=df.iloc[:,1:-1].values
y=df.iloc[:,-1].values

# %% [markdown]
# ## Training the Linear Regression model on the whole dataset

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Training the Polynomial Regression model on the whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
p=PolynomialFeatures(degree=2)
p.fit(x)
xPoly=p.transform(x)
lr2=LinearRegression()
lr2.fit(xPoly,y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Visualising the Linear Regression results

# %%
plt.scatter(x,y,color='red'
)
plt.plot(x,lr.predict(x),color='blue')
plt.title('Position Salary(Linear Regression)')
plt.xlabel('leve')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Visualising the Polynomial Regression results

# %%
plt.scatter(x,y,color='red')
plt.plot(x,lr2.predict(xPoly),color='blue')
plt.title('Position Salary(Polynomial Regression)')
plt.xlabel('Level')
plt.ylabel(
'Salary'
)
plt.show()

# %% [markdown]
# ## Visualising the Polynomial Regression results (for higher resolution and smoother curve)

# %%
x_grid=np.arange(min(x),max(x),0.1)
x_grid=x_grid.reshape((len(x_grid),1))
plt.scatter(x,y,color='red')
plt.plot(x_grid,lr2.predict(p.fit_transform(x_grid)),color='blue')
plt.title('Position Salary(Polynomial Regression)')
plt.xlabel('Level')
plt.ylabel('Salary')
plt.show()
# Out:
# /tmp/ipython-input-9-176979976.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_grid=np.arange(min(x),max(x),0.1)

# %% [markdown]
# ## Predicting a new result with Linear Regression

# %%
lr.predict([[6.5]])
# Out:
# array([330378.78787879])

# %% [markdown]
# ## Predicting a new result with Polynomial Regression

# %%
lr2.predict(p.fit_transform([[6.5]]))
# Out:
# array([189498.10606061])
